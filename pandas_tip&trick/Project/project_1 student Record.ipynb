# %% [markdown]
# # **Students Performance in Exams**

# %% [markdown]
# **Author Name:** *Ahsanullah Ghani*
#
# **Email:** *ahsanullahghani000@gmail.com*
#
#  **The data was Collected from the following**[Link](https://www.kaggle.com/datasets/spscientist/students-performance-in-exams/data)

# %% [markdown]
# # **About Dataset**
# **Context:**
#
# Marks secured by the students
#
# **Content:**
#
# This data set consists of the marks secured by the students in various subjects.
#
# **Acknowledgements:**
#
# http://roycekimmons.com/tools/generated_data/exams
#
# **Inspiration:**
# To understand the influence of the parents background, test preparation etc on students performance

# %% [markdown]
# # **Purpose of this Analysis:**

# %% [markdown]
#  # **1** **Data Loading**

# %% [markdown]
#  **1.1** **Import Libaries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.2** **Import Dataset**

# %%
df = pd.read_csv(r"C:\Users\AHSAN GHANI\Documents\6Month Intership program\Frist Month\pandas_tip&trick\Data set\student_prf\StudentsPerformance.csv")

# %% [markdown]
#  **1.3** **Display First 5 & Last 5 Rows**

# %%
df.head(5) # First 5 Rows
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail(5)# Last 5 Rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# **1.4**  **Check Shape and Columns Name**

# %%
print (f"The Number of Rows in Dataset is {df.shape[0]} & Number of Columns is Dataset is {df.shape[1]}")
# check the shape of dataset
# Out:
# The Number of Rows in Dataset is 1000 & Number of Columns is Dataset is 8

# %%
# Columns name 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %% [markdown]
# # **2** **Data Cleaning**

# %% [markdown]
# **2.1** **Identify the Missing Values**

# %%
df.isnull().sum() # find the Missing Values
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
#    **2.2** **Missing Values Observation**
#
# **There are no missing values in the dataset.** ✅

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **2.3** **Duplicates Rows Observation**
#
# **There are no duplicates rows in the dataset.** ✅

# %% [markdown]
# **2.4** **

# %% [markdown]
# **2.4** **Data types checking**

# %%
df.dtypes # checking the datatypes of data
# Out:
# gender                           str
# race/ethnicity                   str
# parental level of education      str
# lunch                            str
# test preparation course          str
# math score                     int64
# reading score                  int64
# writing score                  int64
# dtype: object

# %% [markdown]
# **2.4** **Data Type Observation**
#
# **All columns have appropriate data types. Text columns are stored as strings, while score columns are stored as integers.** ✅

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# **2.5** **Check Columns Name**

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# # **3** **Data Analysis**

# %% [markdown]
# **3.1** **Summary of data**

# %%
df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %% [markdown]
# **3.2** **Analyze Numerical Columns**

# %%
df.select_dtypes(include='number').describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# **3.3** **Analyze Catagories Columns**

# %%
df.select_dtypes(include="object").columns
# Out:
# C:\Users\AHSAN GHANI\AppData\Local\Temp\ipykernel_6276\3787243251.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").columns
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='str')

# %% [markdown]
# # **4** **Data Exploration**

# %% [markdown]
# **4.1**

# %%
df[df["math score"] < 50]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 9    female        group B                 high school  free/reduced
# 11     male        group D          associate's degree      standard
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 961  female        group D            some high school  free/reduced
# 973  female        group D                some college  free/reduced
# 980  female        group B                 high school  free/reduced
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df["math score"] == 80] ##those student which are obtain 80 score number in math
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 77     male        group A           bachelor's degree      standard
# 186    male        group E                 high school      standard
# 210    male        group D            some high school  free/reduced
# 235    male        group D          associate's degree      standard
# 241  female        group E           bachelor's degree      standard
# 253    male        group D             master's degree      standard
# 303    male        group B          associate's degree      standard
# 359  female        group D                some college      standard
# 376  female        group D            some high school      standard
# 380  female        group B          associate's degree      standard
# 477    male        group D          associate's degree      standard
# 637  female        group D            some high school      standard
# 664    male        group D          associate's degree      standard
# ...

# %%
df[(df['gender']=='female') & (df['math score']== 80 ) ]
# df[(df["gender"] == "female") & (df["math score"] > 80)]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 241  female        group E           bachelor's degree  standard
# 359  female        group D                some college  standard
# 376  female        group D            some high school  standard
# 380  female        group B          associate's degree  standard
# 637  female        group D            some high school  standard
# 711  female        group E            some high school  standard
#
#     test preparation course  math score  reading score  writing score
# 241                    none          80             83             83
# 359                    none          80             90             89
# 376                    none          80             90             82
# 380                    none          80             86             83
# 637               completed          80             92             88
# 711               completed          80             85             85

# %%
df[(df['gender']=='female') | (df['math score']== 80 ) ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # **5** **Data Visulization**

# %% [markdown]
# **5.1** **Heatmap**

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# correlation = df.corr(numeric_only=True)

# sns.heatmap(correlation, annot=True)

# plt.title("Correlation Heatmap")
# plt.show()
import seaborn as sns
import matplotlib.pyplot as plt
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation,annot=True)
plt.title('correlation Heatmap')
plt.show()

# %% [markdown]
# **5.2** **Bar Plot**

# %%
import matplotlib.pyplot as plt

df["gender"].value_counts().plot(kind="bar")

plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Number of Students by Gender")
plt.show()

# %% [markdown]
# **5.3** **Scatter plot**

# %%
plt.scatter(df["math score"], df["reading score"])

plt.xlabel("Math Score")
plt.ylabel("Reading Score")
plt.title("Math Score vs Reading Score")
plt.show()

# %% [markdown]
# # 📊 Project One — Student Performance in Exams
#
# ## 🚀 About the Project
#
# I have successfully completed **Project One: Student Performance in Exams** as part of my **Data Science learning journey at Devsil**.
#
# In this project, I worked with student performance data and practiced **Data Analysis and Data Visualization using Python**.
#
# ---
#
# ## 🛠️ Tools & Libraries
#
# - 🐍 Python
# - 🐼 Pandas
# - 🔢 NumPy
# - 📈 Matplotlib
# - 🎨 Seaborn
# - 📓 Jupyter Notebook
#
# ---
#
# ## 📌 What I Learned
#
# During this project, I learned how to:
#
# - Load and explore the dataset
# - Check the shape and structure of data
# - Analyze numerical columns
# - Analyze categorical columns
# - Find missing values
# - Check duplicate values
# - Check data types
# - Apply filtering conditions
# - Find patterns and trends
# - Analyze relationships between numerical variables
# - Create different data visualizations
# - Create correlation heatmaps
#
# ---
#
# ## 📊 Data Visualization
#
# I created different visualizations to understand the data better:
#
# - 📊 Bar Chart
# - 🔵 Scatter Plot
# - 🔥 Correlation Heatmap
#
# These visualizations helped me understand the **distribution, relationships, patterns, and trends** in the student performance data.
#
# ---
#
# ## 🎯 Project Goal
#
# The main goal of this project was to understand **Exploratory Data Analysis (EDA)** and learn how to find useful insights from the **Student Performance in Exams** dataset.
#
# ---
#
# ## 🌱 My Learning Journey
#
# I am currently learning **Data Science at Devsin** and improving my skills through practical projects.
#
# This project helped me strengthen my knowledge of:
#
# **Python → Data Analysis → Data Visualization → EDA**
#
# ---
#
# ## 💡 Key Learning
#
# > Data becomes more meaningful when we explore it, visualize it, and understand the patterns hidden inside it.
#
# ---
#
# ## ✅ Project Status
#
# ### 🎉 Project One — Completed
#
# **Project:** Student Performance in Exams
#
# **Learning:** Data Science & Exploratory Data Analysis
#
# **Next Goal:** Keep learning, keep practicing, and build more Data Science projects. 🚀
